# %%
from langchain_huggingface import HuggingFacePipeline

llm = HuggingFacePipeline.from_model_id(
    model_id='Qwen/Qwen2.5-1.5B-Instruct',
    task='text-generation',
    pipeline_kwargs={
        'max_new_tokens':10
    }
)
# Out:
# Loading weights: 100%|██████████| 338/338 [00:00<00:00, 3158.90it/s]
# [transformers] Passing `generation_config` together with generation-related arguments=({'max_new_tokens'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.

# %%
prompt="What is the mergesort algorithm ? Please write code for it as well"

response = llm.invoke(prompt)
print(response)
# Out:
# [transformers] Both `max_new_tokens` (=10) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# What is the mergesort algorithm ? Please write code for it as well. Mergesort is a popular divide-and
