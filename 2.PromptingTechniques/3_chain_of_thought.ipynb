# %%
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()
client = OpenAI()

# %%
# Q = ("Roger has 5 tennis balls. He buys 2 more cans of tennis balls. "
#      "Each can has 3 tennis balls. How many tennis balls does he have now?")

# # --- Failure demo: base model, Completions API ---
# fail = client.completions.create(
#     model="davinci-002",
#     prompt=f"Q: {Q}\nA: The answer (just the number) is",
#     max_tokens=5, temperature=0
# )
# print("davinci-002 direct:", fail.choices[0].text)

# %%
Q = ("Roger has 5 tennis balls. He buys 2 more cans of tennis balls. "
     "Each can has 3 tennis balls. How many tennis balls does he have now?")

# --- Failure demo: base model, Completions API ---
fail2 = client.completions.create(
    model="gpt-4o-mini",
    prompt=f"Q: {Q}\nA: The answer (just the number) is",
    max_tokens=5, temperature=0
)
print("Gpt 4o mini says:", fail2.choices[0].text)
# Out:
# Gpt 4o mini says:  11.
#
# Q

# %%
Q = ("Roger has 5 tennis balls. He buys 2 more cans of tennis balls. "
     "Each can has 3 tennis balls. How many tennis balls does he have now?")

# --- Failure demo: base model, Completions API ---
passing = client.completions.create(
    model="gpt-4o-mini",
    prompt=f"Q: {Q}\nA: The answer is",
    max_tokens=5, temperature=0
)
print("Gpt 4o mini says:", passing.choices[0].text)
# Out:
# Gpt 4o mini says:  11 tennis balls.

# %%
Q = ("Roger has 5 tennis balls. He buys 2 more cans of tennis balls. "
     "Each can has 3 tennis balls. How many tennis balls does he have now?")

# --- Failure demo: base model, Completions API ---
try4 = client.completions.create(
    model="davinci-002",
    prompt=f"Q: {Q}",
    max_tokens=500, temperature=0
)
print("davinci-002 says:", try4.choices[0].text)
# Out:
# ---------------------------------------------------------------------------
# InternalServerError                       Traceback (most recent call last)
# Cell In[12], line 5
#       1 Q = ("Roger has 5 tennis balls. He buys 2 more cans of tennis balls. "
#       2      "Each can has 3 tennis balls. How many tennis balls does he have now?")
#       3
#       4 # --- Failure demo: base model, Completions API ---
# ----> 5 try4 = client.completions.create(
#       6     model="davinci-002",
#       7     prompt=f"Q: {Q}",
#       8     max_tokens=500, temperature=0
#
# File c:\Micah\ALGOCAMP_AI_ENGINEERING_COURSE\AI_CONCEPTS_GITHUB_REPO\AiEngineeringConcepts\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# ...
