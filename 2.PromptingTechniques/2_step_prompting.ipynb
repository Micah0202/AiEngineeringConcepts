# %%
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()
client = OpenAI()

# %%
system_prompt = """You are a travel planning assistant. For every request, follow these steps in order and show your reasoning before moving on:

Step 1 — Understand constraints
- List the destination, trip length, number of travelers, and total budget.
- Note any must-haves (e.g. accommodation, food, transport, activities).

Step 2 — Allocate the budget
- Split the total budget across categories: accommodation, food, local transport, activities, and a small buffer for unexpected costs.
- Show the dollar amount (or percentage) assigned to each category and explain why.

Step 3 — Choose accommodation
- Pick an option that fits the accommodation budget (hostel, budget hotel, etc.).
- State nightly cost, number of nights, and total accommodation spend.

Step 4 — Plan daily transport
- Estimate cost for getting around (subway pass, buses, walking where free).
- Give a daily transport cost and a 3-day total.

Step 5 — Plan meals
- Set a realistic daily food budget (breakfast, lunch, dinner).
- Suggest affordable options (e.g. delis, food carts, casual spots) without naming only expensive restaurants.

Step 6 — Plan activities (one paid activity per day)
- For each day, propose one paid activity with its cost.
- Include free highlights where possible to stay within budget.

Step 7 — Build the day-by-day itinerary
- Day 1, Day 2, Day 3: morning, afternoon, evening with activities and rough timing.

Step 8 — Final check
- Add up all costs (accommodation + transport + food + activities + buffer).
- Confirm the total is at or under the user's budget; if over, suggest one adjustment.

End with a short summary: final itinerary and total estimated cost."""

user_query = """Plan a 3-day trip to New York City for one person with a total budget of $500.
Include accommodation, food, local transport, and at least one paid activity each day.
Think step by step before giving the final itinerary."""

response = client.responses.create(
    model="gpt-4o-mini",
    instructions=system_prompt,
    input=user_query,
)

print(response.output_text)
# Out:
# Sure! Let’s plan a 3-day trip to New York City for one person with a total budget of $500. I will follow the steps outlined.
#
# ### Step 1 — Understand constraints
# - **Destination**: New York City
# - **Trip Length**: 3 days
# - **Number of Travelers**: 1
# - **Total Budget**: $500
# - **Must-Haves**: Accommodation, food, local transport, at least one paid activity per day.
#
# ### Step 2 — Allocate the budget
# To make the most of the budget, I will allocate funds across categories:
#
# - **Accommodation**: $150 (30%)
# - **Food**: $120 (24%)
# - **Local Transport**: $60 (12%)
# - **Activities**: $120 (24%)
# - **Buffer for unexpected costs**: $50 (10%)
#
# **Reasoning**:
# - Accommodation takes a significant portion due to New York’s high costs.
# - Food is important but can be managed with affordable choices.
# - Local transport is essential for getting around the city.
# - Activities are budgeted to ensure enjoyable experiences.
# - A buffer is always wise in case of unforeseen expenses.
#
# ### Step 3 — Choose accommodation
# I recommend a budget-friendly hostel or hotel:
# - **Option**: HI New York City Hostel
#   - **Nightly Cost**: $50
#   - **Total Nights**: 3
#   - **Total Accommodation Spend**: $150
#
# ### Step 4 — Plan daily transport
# Using public transport is economical:
# - **Daily Transport Cost**: $10 (for a MetroCard)
# - **Total for 3 days**: $30
#
# ### Step 5 — Plan meals
# Setting a realistic daily food budget:
# - **Daily Food Budget**: $10 (about $3 for breakfast, $4 for lunch, $3 for dinner)
# - **Total for 3 days**: $30
# - **Affordable Options**: Bagels for breakfast, street food or delis for lunch, and casual dining like pizza for dinner.
#
# ### Step 6 — Plan activities (one paid activity per day)
# 1. **Day 1**: Visit the **Metropolitan Museum of Art** - Cost: $25 (pay what you wish).
# 2. **Day 2**: Take the **Statue of Liberty and Ellis Island ferry** - Cost: $24.
# 3. **Day 3**: Go to the **Top of the Rock Observation Deck** - Cost: $38.
#
# ### Summary of Costs So Far
# - **Accommodation**: $150
# - **Local Transport**: $30
# - **Food**: $30
# - **Activities**:
#   - Day 1: $25
#   - Day 2: $24
#   - Day 3: $38
#   - **Total Activities**: $87
#
# ### Step 7 — Build the day-by-day itinerary
# - **Day 1**:
#   - **Morning**: Arrive and check-in at HI New York City Hostel.
#   - **Afternoon**: Visit the Metropolitan Museum of Art.
#   - **Evening**: Dinner from a local deli and explore Central Park.
#
# - **Day 2**:
#   - **Morning**: Breakfast at a nearby bagel shop.
#   - **Afternoon**: Take the ferry to Statue of Liberty and Ellis Island.
#   - **Evening**: Dinner at a pizzeria and stroll around Lower Manhattan.
#
# - **Day 3**:
#   - **Morning**: Breakfast at a food cart.
#   - **Afternoon**: Visit Top of the Rock for skyline views.
#   - **Evening**: Casual dinner and explore Times Square.
#
# ### Step 8 — Final Check
# - **Total Costs**:
#   - Accommodation: $150
#   - Local Transport: $30
#   - Food: $30
#   - Activities: $87
#   - **Total**: $397
#
# Add the buffer: $50
# - **Grand Total**: $447
#
# **Total Estimated Cost**: $447
#
# ### Summary
# - Total itinerary cost: $447 (well within the $500 budget).
# - Accommodation at HI New York City Hostel ($150), local transport ($30), daily food budget ($30), and activities ($87).
# - You’ll have a budget of $53 leftover for extra experiences or souvenirs.
#
# Enjoy your trip!
